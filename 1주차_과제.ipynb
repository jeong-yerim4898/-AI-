# %% [markdown]
# <a href="https://colab.research.google.com/github/jeong-yerim4898/-AI-/blob/master/1%EC%A3%BC%EC%B0%A8_%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 언어 음성 이미지 자율주행
#
# 4가지 제품 및 서비스

# %% [markdown]
# # **1. 언어**

# %% [markdown]
# > ### <구글 **"Bert"**>

# %% [markdown]
# >>![image.png](data:image/png;base64,...)

# %% [markdown]
# >**Bert란?**
# >> 2018년 구글이 공개한 인공지능 언어모델 'Bidirectional Encoder Representations from Transformers'약자로 자연 언어 처리(NLP) 딥러닝 모델이다.
#
# >> 언어표현 사전학습의 새로운 방법으로 그 의미는 '큰 텍스트 코퍼스(Wikipedia와 같은)'를 이용하여 범용목적의 '언어 이해'(language understanding)' 모델을 훈련시키는 것과 그 모델에 관심 있는 실제의 자연 언어 처리 태스크(질문·응답 등)에 적용한 것이다.
#
# >> BERT는 자연언어 처리 태스크를 교육 없이 양방향으로 사전학습하는 첫 시스템이다. 웹(Web)사에서 막대한 양의 보통 텍스트 데이터가 여러 언어로 이용 가능하기 때문에 중요한 특징으로 꼽힌다.

# %% [markdown]
# >**구글검색에 도입된 'BERT'**

# %% [markdown]
# >>구글은 영어 문장 모음을 가져와서 단어의 15%를 무작위로 제거한 다음 버트가 해당 단어의 의미를 파악하는 방식으로 사전훈련 작업을 진행한다.
#
# >>구글 수석 연구원 제프 딘(Jeff Dean)은 "시간이 흐르면서 이같은 훈련은 자연어 처리 알고리즘이 '이해하는(understand)' 맥락에서 매우 효과적인 것으로 확인됐다"고 밝혔다.
#
# >>예를 들어 **'2019 brazil traveler to usa need a visa(2019년 브라질인이 미국에 여행가는 데 비자가 필요한가)'**라는 질문에서 *'~에(to)'*라는 문장과 다른 문장의 상관관계는 그 의미를 이해하는 데 특히 중요하지만, 이전까지의 알고리즘은 이 연관성의 중요성을 이해하지 못해 '브라질로 여행하는 미국인'에 관한 엉뚱한 검색결과를 내놨다. 버트 알고리즘은 ~에(to)와 같은 흔한 문장에서 질문의 늬앙스를 이해하고 사용자에게 정확한 검색결과를 제공한다.
#
# >![image.png](data:image/png;base64,...)

# %% [markdown]
# > **ETRI, 한국어 기반 KorBERT공개**
#
# >> 한국전자통신연구원(ETRI)은 엑소브레인 사업에서 한국어를 활용한 인공지능 서비스 개발에 필요한 한국어 언어모델인 코버트(KorBERT)를 공개했다.
#
# >>ETRI가 공개한 언어모델은 구글의 언어표현 방식에 더 많은 **한국어 데이터를 추가한 언어모델**과 **한국의 교착어 특성까지 반영해 만든 언어모델** 두가지 종류이다.
#
# >> 구글은 40여 만 건의 위키백과 문서 데이터를 사용해 한국어 모델을 개발한 반면 ETRI 연구진은 23GB에 달하는 10년간의 신문기사와 백과사전 정보를 도해 45억개의 형태소를 학습시켰다.
#
# >>한글은 다른 언어와 달리 어근에 조사가 붙는 교착어 이므로 한국어의 의미 최소 단위인 형태소까지 고려해 한국어의 특정을 최대한 반영한 모델을 만들었다. 성능을 확인하는 5가지 기준에서 구글보다 평균 4.5%가량 개선되었다.
#
# >> **이번에 공개한 KorBERT를 통해 한국어 분석, 지식추론, 질의응답 등의 다양한 한국어 딥러닝 기술의 고도화가 가능할 것으로 보인다. 한국어를 기반으로한 딥러닝 연구, 교육 등의 목적으로 대학이나 기업, 기관의 개발자들이 많이 활용할 수 있을 것으로 기대된다.**

# %% [markdown]
# >### **[언어 : 나의 생각]**
#
# >>빅데이터를 공부하며 숫자와 이미지와 비교하면 언어로 관련된 기술이 많이 어렵다는 사실을 듣게되었다. 특히 한글은 영어보다 더 어려운 언어로 더 많은 연구와 자료가 필요하다고 했다. 이번 조사를 통해 불과 6개월 사이에 느꼈던 어려움 보다 한발 더 인공지능에 한글이 다가간거 같아 흥미가 생겼다. 어렵다 할 뿐이지 불가능 하다는 뜻이 아니라는 것을 알게되었다. 빅데이터를 숫자들 속에서 인사이트를 발견해야 한다라는 고정관념에 박혀있는 자신도 알게 되었다. 어렵다는 선입견에 빠져 한정된 주제를 가지고 연구를 진행하기 보다 관심있다면 주제를 과감하게 선정하고 그에 맞춰 발전하는 연구를 하고 싶다는 생각을 가지게 되었다.

# %% [markdown]
# # **2. 음성**

# %% [markdown]
# > ### **<KT, 화물차앱 AI음성인식>**
#
# >>냉장고, 에어컨, 자동차 등 각종 기기에 소프트웨어를 탑재하면 음성인식 등 기가지니를 이용할 수 있는 클라우드 AI 플랫폼인 기가지니 인사이드 기반으로 이루어졌다.
#
# >> 이러한 플랫폼이 고트럭에 적용되며 고트럭 이용자는 운전 중 **음성명령 만으로 현재위치 확인, 화물차 우대주유소 찾기 등을 이용할 수 있다.** 소속 물류회사와 협회에서 제공하는 공지사항과 상용차신문에서 제공하는 뉴스를 청취하는 것도 가능하다.
#
# >> 이 외에 일구하기, 차량 관리매장 안내 등 편리한 기능을 두루 갖추며 2개월 만에 **누적 다운로드 12만, 가입회원 6만을 넘었다.**

# %% [markdown]
# > ### **<감정까지 잡아내는 AI음성인식>**
#
# >> 최근에 AI가 결합된 음성인식 기술은 텍스트 변환 단계를 넘어 화자가 사용하는 단어와 목소리 톤을 분석해 감정까지 잡아내는 *'지능형 컨택센터'*에 한 발짝 다가서고 있다.
#
# >> *지능형 컨텍센터*가 가능해 진다면 고객상담센터에 전화화는 고객은 기다릴 필요 없이 음성로봇이 문의에 답변한다.

# %% [markdown]
# > ### **<삼성, 인터넷 연결 안해도 되는 실시간 AI통역 기술>**
#
# >>삼성전자는 삼성전자 종합기술원에서 개발한 실시간 통역 시스템을 2019년 처음 공개했다. AI포럼에서 구글과 1:1로 정면 비교하는 시간을 마련했다. 삼성 빅스비는 말한 내용을 정확하게 통역했고 구글 번역기는 오류가 지속적으로 발생했다.
#
# >> 기존 AI번역과 음성인식을 합치고 딥러닝 기술을 더해 '실시간 통역 서비스'를 선보였다. 특히, 서버를 거치지 않는다는 게 핵심이다. 서버를 거치지 않으면 데이터나 전력소모가 줄어드는 장점이 있다. 해외 유수기업도 이미 선보였지만 품질이 낮다는 평가를 받았다. 삼성은 통역 반응 속도를 높였고 딥러닝 기술을 적용해 통력 정확성을 대폭 높였다.

# %% [markdown]
# >### **[음성 : 나의 생각]**
#
# >>전 세계에는 7천 개 이상의 언어가 있지만 72억 인구의 3분의 2는 주요 12개 언어를 모국어로 쓰고 있다. 주로 많이 사용되는 언어는 영어, 중국어가 많이 사용된다. 하지만 한류의 영향과 빠르게 배워 읽고 쓰기가 가능한 한글의 영향력도 커지고 있다. AI기술을 선도하고 있는 나라는 많이 사용되는 언어 순위 만큼 미국과 중국이 앞서 나가고 있다. 그에 따라 자연스럽게 영어와 중국어를 인식하는 인공지능 기술은 급속으로 발전하고 있다. 언택트 시대에 맞춰 인공지능 스피커의 이용률이 높아지는 만큼 우리 한글의 음성인식은 한국에서 연구를 주도적으로 이끌어 가야한다고 생각한다. 누구보다 한글의 의미,상황을 잘 알고 있는 사람은 대한민국 국민이기 때문이다. 영어와 중국어 만큼 자연스러운 음성인식 기술이 발전한다면 현재 한글열풍에서 새로운 위치를 선점할 수 있다고 생각한다.
#
# >구글에서 한글 번역을 제공하지만 대부분 국민이 느끼기에 어색한 느낌은 여전히 남아있다. 이번 삼성 번역기 조사를 통해 한글을 번역하는 기술의 발전의 소중함과 중요성을 느낄 수 있었다. 미국 기업인 구글과 1:1 비교를 진행한 모습을 보고 많은 생각이 들었다. 한국 기업이 미국기업보다 자연스러운 한글 번역은 당연한 모습이 아닌가? 라는 생각이 들었다. 하지만 이 당연한 생각을 이루기 위해서는 많은 노력과 연구가 필요하다는 생각도 같이 들었다. 학창시절 문법이 어렵다는 생각으로 깊게 이해보다 암기 공부 방식을 주로 적용하였다. 하지만 음성인식 기술의 발전으로 한국의 또 다른 힘을 보여주기 위해서는 가장 기본인 한글의 문법에 대해 중요성을 다시 느낄 수 있었다. 결국 기술의 발전은 신기술 역시 중요하지만 적용하기 위한 언어, 숫자 등 기본이론 역시 중요하다.

# %% [markdown]
# # **3. 이미지**

# %% [markdown]
# > ### **<로민, AI 문자인식(OCR) 솔루션>**
#
# >> AI 문서인식 텍스트스코프(Textscope)는 딥러닝 기반의 엔진을 활용해 스마트폰 촬영 이미지와 팩스 이미지 등 비정형 문서 이미지에서 높은 정확도로 문자를 인식한다.
#
# >> 예전에는 종이문서를 스캔하여 문자를 인식했으나 최근에는 고객이 직접 스마트폰으로 촬용한 문서 이미지를 금융과 보험 업무에 사용하는 경우가 늘어나며 OCR 기술 활용 범위가 넓어졌다.
#
# >> 로민의 핵심기술인 실환경 문자인식 기술(Scence Text Recognition)을 적용해 어둡거나 흔들리게 촬영된 문서 이미지, 노이지가 심한 팩스 문서 이미지 등에서도 높은 인식률을 기록한다. 통장사본과 처방전 등 정해진 양식이 없거나 양식이 다양해 문자인식이 쉽지 않는 문서 이미지도 AI를 활용해 손쉽게 읽고 종류를 자동으로 분류한다.

# %% [markdown]
# > ### **<딥페이크(Deep Fake)>**
#
# >> 딥페이크란 AI 기술 중 하나인 딥러닝과 Fake를 조합한 합성어로 허위 동영상 콘텐츠를 만들거나 변형하는데 사용되는 AI기반 기술을 의미한다. AI기술과 안면 매핑(facial mapping) 또는 안면 스와핑(faceswqpping) 기술을 이용하여 특정 인물의 얼굴과 신체부위를 전혀 다른 영상과 합성해 새로운 영상을 만들어 낼 수 있다.
#
# >> 가짜 이미지를 만들어내는 기술은 예전부터 존재 했지만, AI와 결합하면서 비약적으로 발전하게 되었다. 가장 큰 문제는 누구도 무엇이 진짜인지 가짜인지 구별할 수 없다는 것이다. 이미 세계 각국에서 다양한 딥페이크 약용 사례가 발생하고 있으며 미국과 유럽에서는 대응할 수 있는 기술 및 법제마련을 위해 적극적인 노력을 기울이고 있다.
#
# >> 항상 이 기술에 장점도 있다. AI로 만들어낸 고해상도 얼굴 사진은 실제 인물 사진이 아니기 때문에 초상권도 저작권도 없이 사용할 수 있다.

# %% [markdown]
# > ### **<이미지 인식을 통한 추천서비스>**
#
# >>비비노(Vinino)는 스마트폰으로 와인 라벨만 찍으면 가격과 평점, 어룰리는 안주까지도 추천해주는 어플을 통해 전문가 테이스팅 리뷰까지 제고한다. 약 100만명의 애주가 및 전문가가 500만 건의 테이스팅 리뷰를 남겼다. 2500만 명이 어플을 다운로드 했고 고객들은 약 4억개의 라벨을 스캔해 와인에 대한 정보를 얻었다.
#
# >>엔트러피(Entrupy)는 명픔울 실시간으로 판별해주는 인공지능이다. 전 세계적으로 '짝통'상품 판매는 세계 무역의 7%를 차지한다. 최근 위조 기술도 매우 고도화되어 전문가라 해도 육안으로 구분해내기 쉽지 않다. 이 시스템은 가방, 신발 등 명품제품의 표면을 사진으로 찍으면 300만장의 사진을 학습한 AI가 이미지를 분석하여 진품 여부를 판별해 준다. 제품을 현미경 사진으로 찍은 다음 사물을 260배 확대하여 육안으로 찾아내기 어려운 비정상적인 패턴, 즉 인장이나 가죽 잔주름 사이의 작은 공백, 페인트칠 등을 보고 진품 여부를 판별한다. 이 시스템의 정확도는 98%이며 일상 중 언제 어디서든 진품 판별이 팔요할 때 15초의 시간으로 확인이 가능하다.

# %% [markdown]
# >### **[이미지 : 나의 생각]**
#
# >>이미지는 사람의 5대 감각 중 많은 영향을 주는 감각중 하나이다. 시각을 통해 받아들이는 정보의 양이 많은 만큼 많은 관심을 가지고 연구하는 분야이다. 문자를 인식하고 제품을 인식하는 기술은 우리 삶속에 편리함을 가져다 줄 것이라 많이 생각한다. 하지만 딥페이크와 같이 악영향을 끼치는 기술은 많은 생각을 해볼 필요가 있다. 많은 사람들이 뉴스를 통해 봤을 Fake news가 대표적인 사레라고 생각한다. 특히 미국같은 중요한 역할을 수행하는 대통령을 모델로 만든 fake news 심각한 문제를 일으킬 수 있다. 고도로 발전하는 인공지능에 맞춰 딥페이크의 기술 또한 정교해지며 발견하기 어려워 질 수 있다. 하지만 딥페이크의 악용 사례로 기술을 금지하기에는 유용한 사례도 있다. 개인의 초상권, 저작권이 중요해진 현대 사회에서 딥페이크 기술을 활용해 가상의 얼굴, 모델 이미지를 만들어 이용할 수 있다. 초상권이 없기 때문에 문서작성시 다양한 이미지를 이용 할 수 있고 쇼핑몰은 모델의 인건비를 줄일 수 있다. 이처럼 모든 기술에는 장단점이 모두 존재한다고 생각한다. 기술의 발전만큼 기술을 감시하고 막을 수 있는 보안기술 역시 같은 속도로 더 나아가 빠른 속도로 발전해야 한다고 생각한다.

# %% [markdown]
# # **4. 자율주행**

# %% [markdown]
# > ### **<이미지 인식을 통한 추천서비스>**
